# %%
# Import Modules

import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %%
# Import Datasets

corona_dataset_csv = pd.read_csv('/Users/joerussell/Desktop/DATASCIENCE/DATASETS/time_series_covid19_confirmed_global.csv')
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...   7/2/21  \
# 0        0        0        0        0        0        0  ...   120216
# ...

# %%
corona_dataset_csv.shape
# Out:
# (279, 541)

# %%
# Delete useless columns

corona_dataset_csv.drop(['Lat', 'Long'], axis=1, inplace=True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...   7/2/21  \
# 0        0        0        0        0        0        0  ...   120216
# ...

# %%
# Aggregate by country

corona_dataset_aggregated = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  7/2/21  7/3/21  7/4/21  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...  120216  120216  120216
# Albania               0        0        0  ...  132526  132534  132535
# Algeria               0        0        0  ...  140550  141007  141471
# Andorra               0        0        0  ...   13918   13918   13918
# Angola                0        0        0  ...   39089   39172   39230
#
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (195, 537)

# %%
# Visualizing data for countries

corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %%
# Calculating a good measure

corona_dataset_aggregated.loc['China'][:3].plot()
# Out:
# <AxesSubplot:>

# %%
# Calculate first derivative of the curve

corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %%
# Find maximum infection rate for China

corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 40902.0

# %%
corona_dataset_aggregated.loc['Spain'].diff().max()
# Out:
# 93822.0

# %%
# Find maximum infection rate for all countries

countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
corona_dataset_aggregated['max_infection_rate'] = max_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  7/3/21  7/4/21  7/5/21  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...  120216  120216  125937
# Albania               0        0        0  ...  132534  132535  132537
# Algeria               0        0        0  ...  141007  141471  141966
# Andorra               0        0        0  ...   13918   13918   13918
# Angola                0        0        0  ...   39172   39230   39300
#
# ...

# %%
# Create a new dataframe with only needed column

corona_data = pd.DataFrame(corona_dataset_aggregated['max_infection_rate'])

# %%
corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                 5721.0
# Albania                     1239.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       405.0

# %%
# Import WHR Dataset

happiness_report_csv = pd.read_csv('/Users/joerussell/Desktop/DATASCIENCE/DATASETS/2019.csv')

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# Drop useless columns

useless_cols = ['Overall rank', 'Score', 'Generosity', 'Perceptions of corruption']
happiness_report_csv.drop(useless_cols, axis=1, inplace=True)
happiness_report_csv.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
# Change indices of the dataframe

happiness_report_csv.set_index('Country or region', inplace=True)
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
# Join the two datasets

corona_data.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                 5721.0
# Albania                     1239.0
# Algeria                     1133.0
# Andorra                      299.0
# Angola                       405.0

# %%
corona_data.shape
# Out:
# (195, 1)

# %%
happiness_report_csv.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape
# Out:
# (156, 4)

# %%
data = corona_data.join(happiness_report_csv, how='inner')
data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan              5721.0           0.350           0.517
# Albania                  1239.0           0.947           0.848
# Algeria                  1133.0           1.002           1.160
# Argentina               41080.0           1.092           1.432
# Armenia                  2476.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
# Correlation matrix

data.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.112009
# GDP per capita                          0.112009        1.000000
# Social support                          0.052154        0.757521
# Healthy life expectancy                 0.079783        0.859431
# Freedom to make life choices           -0.051774        0.394799
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.052154                 0.079783
# GDP per capita                      0.757521                 0.859431
# Social support                      1.000000                 0.751632
# Healthy life expectancy             0.751632                 1.000000
# Freedom to make life choices        0.456317                 0.423146
#
#                               Freedom to make life choices
# max_infection_rate                               -0.051774
# ...

# %%
# Visualization of results

data.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan              5721.0           0.350           0.517
# Albania                  1239.0           0.947           0.848
# Algeria                  1133.0           1.002           1.160
# Argentina               41080.0           1.092           1.432
# Armenia                  2476.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
# Plotting GDP vs maximum infection rate

x = data['GDP per capita']
y = data['max_infection_rate']
sns.scatterplot(x, np.log(y))
# Out:
# /Users/joerussell/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# /Users/joerussell/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
# Plotting Social support vs maximum infection rate

# %%
x = data['Social support']
y = data['max_infection_rate']
sns.scatterplot(x, np.log(y))
# Out:
# /Users/joerussell/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.regplot(x, np.log(y))
# Out:
# /Users/joerussell/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Social support', ylabel='max_infection_rate'>

# %%
# Plotting Healthy life expectancy vs maximum infection rate

x = data['Healthy life expectancy']
y = data['max_infection_rate']
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='max_infection_rate'>

# %%
# Plotting Freedom to make life choices vs maximum infection rate

x = data['Freedom to make life choices']
y = data['max_infection_rate']
sns.scatterplot(x=x, y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>

# %%
sns.regplot(x=x, y=np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='max_infection_rate'>
